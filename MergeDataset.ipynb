# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: C:\Users\ALIEFAKMAL\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# File paths
file_path1 = r"C:\Users\ALIEFAKMAL\Documents\DEGREE\Semester 6\CSP650\FYP Dataset\2 label 2.csv"
file_path2 = r"C:\Users\ALIEFAKMAL\Documents\DEGREE\Semester 6\CSP650\FYP Dataset\2 label 3.csv"

# Read the CSV files into DataFrames
df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)

# Concatenate the DataFrames
merged_df = pd.concat([df1, df2], ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_file_path = r"C:\Users\ALIEFAKMAL\Documents\DEGREE\Semester 6\CSP650\FYP Dataset\merged_file.csv"
merged_df.to_csv(merged_file_path, index=False)

print(f"Files merged successfully and saved to {merged_file_path}")
# Out:
# Files merged successfully and saved to C:\Users\ALIEFAKMAL\Documents\DEGREE\Semester 6\CSP650\FYP Dataset\merged_file.csv
